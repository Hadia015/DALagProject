# %%
num = int(input("Enter a number: "))
if num % 4 == 0:
  print("Great! This number is a multiple of 4.")
elif num % 2 == 0:
  print("Terrific! This is an even number.")
else:
  print("Nice! This is an odd number.")
# Out:
# Enter a number: 7
# Nice! This is an odd number.
