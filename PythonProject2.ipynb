# %% [markdown]
# <a href="https://colab.research.google.com/github/Hadia015/DALagProject/blob/main/PythonProject2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import pandas
import pandas as pd

# %%
#import csv
df= pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
#data exploration
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.shape
# Out:
# (101766, 50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
print(df.columns)
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
#data cleaning task
drop_columns=['age', 'weight','admission_type_id', 'discharge_disposition_id', 'admission_source_id','time_in_hospital','max_glu_serum', 'A1Cresult','metformin', 'repaglinide', 'nateglinide', 'chlorpropamide','glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide','pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone','tolazamide', 'examide', 'citoglipton', 'insulin','glyburide-metformin', 'glipizide-metformin','glimepiride-pioglitazone', 'metformin-rosiglitazone','metformin-pioglitazone']
df.drop(drop_columns, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'payer_code',
#        'medical_specialty', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses',
#        'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
print(df['gender'])
# Out:
# 0         Female
# 1         Female
# 2         Female
# 3           Male
# 4           Male
#            ...
# 101761      Male
# 101762    Female
# 101763      Male
# 101764    Female
# 101765      Male
# Name: gender, Length: 101766, dtype: object

# %%
#pick any group as an initial comparison point- male patients
male_df=df[df['gender']=='Male']
print(male_df)
# Out:
#         encounter_id  patient_nbr             race gender payer_code  \
# 3             500364     82442376        Caucasian   Male          ?
# 4              16680     42519267        Caucasian   Male          ?
# 5              35754     82637451        Caucasian   Male          ?
# 6              55842     84259809        Caucasian   Male          ?
# 7              63768    114882984        Caucasian   Male          ?
# ...              ...          ...              ...    ...        ...
# 101753     443841992    184875899            Other   Male          ?
# 101759     443842778     86472243        Caucasian   Male         MC
# 101761     443847548    100162476  AfricanAmerican   Male         MC
# 101763     443854148     41088789        Caucasian   Male         MC
# 101765     443867222    175429310        Caucasian   Male          ?
#
#        medical_specialty  num_lab_procedures  num_procedures  num_medications  \
# ...

# %%
#descriptive statistics
male_df.describe()
# Out:
#        encounter_id   patient_nbr  num_lab_procedures  num_procedures  \
# count  4.705500e+04  4.705500e+04        47055.000000    47055.000000
# mean   1.658648e+08  5.460650e+07           43.030964        1.449899
# std    1.033094e+08  3.882671e+07           19.600972        1.791613
# min    1.668000e+04  1.629000e+03            1.000000        0.000000
# 25%    8.437063e+07  2.345622e+07           32.000000        0.000000
# 50%    1.528869e+08  4.522258e+07           44.000000        1.000000
# 75%    2.318417e+08  8.774224e+07           56.000000        2.000000
# max    4.438672e+08  1.895026e+08          132.000000        6.000000
#
#        num_medications  number_outpatient  number_emergency  number_inpatient  \
# count     47055.000000       47055.000000      47055.000000      47055.000000
# mean         15.828775           0.353714          0.176708          0.615705
# std           8.409145           1.231802          0.776532          1.220893
# ...

# %%
#picking a feature/measure/score 'num_medications'
male_df['num_medications'].describe()
# Out:
# count    47055.000000
# mean        15.828775
# std          8.409145
# min          1.000000
# 25%         10.000000
# 50%         14.000000
# 75%         20.000000
# max         81.000000
# Name: num_medications, dtype: float64

# %%
#compare above group to a different group- female patients
female_df=df[df['gender']=='Female']
print(female_df)
# Out:
#         encounter_id  patient_nbr             race  gender payer_code  \
# 0            2278392      8222157        Caucasian  Female          ?
# 1             149190     55629189        Caucasian  Female          ?
# 2              64410     86047875  AfricanAmerican  Female          ?
# 8              12522     48330783        Caucasian  Female          ?
# 9              15738     63555939        Caucasian  Female          ?
# ...              ...          ...              ...     ...        ...
# 101757     443842136    181593374        Caucasian  Female          ?
# 101758     443842340    120975314        Caucasian  Female         MC
# 101760     443847176     50375628  AfricanAmerican  Female         DM
# 101762     443847782     74694222  AfricanAmerican  Female         MC
# 101764     443857166     31693671        Caucasian  Female         MC
#
#                medical_specialty  num_lab_procedures  num_procedures  \
# ...

# %%
#descriptive statistics
female_df.describe()
# Out:
#        encounter_id   patient_nbr  num_lab_procedures  num_procedures  \
# count  5.470800e+04  5.470800e+04        54708.000000      54708.0000
# mean   1.646297e+08  5.409153e+07           43.151769          1.2449
# std    1.020601e+08  3.858307e+07           19.737012          1.6224
# min    1.252200e+04  1.350000e+02            1.000000          0.0000
# 25%    8.550109e+07  2.338585e+07           31.000000          0.0000
# 50%    1.518824e+08  4.578898e+07           44.000000          1.0000
# 75%    2.288644e+08  8.736580e+07           57.000000          2.0000
# max    4.438572e+08  1.894815e+08          129.000000          6.0000
#
#        num_medications  number_outpatient  number_emergency  number_inpatient  \
# count     54708.000000       54708.000000      54708.000000      54708.000000
# mean         16.187888           0.382832          0.216020          0.652683
# std           7.873664           1.296883          1.044577          1.297669
# ...

# %%
#picking a feature/measure/score 'num_medications'
female_df['num_medications'].describe()
# Out:
# count    54708.000000
# mean        16.187888
# std          7.873664
# min          1.000000
# 25%         11.000000
# 50%         15.000000
# 75%         20.000000
# max         75.000000
# Name: num_medications, dtype: float64

# %%
#visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#removing Unknown/Invalid from gender
df = df[df['gender'] != 'Unknown/Invalid']

# %%
#plot using a barplot
sns.barplot(x='gender', y='num_medications', data=df)
plt.title('Number of Medications by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Medications')
plt.show()

# %%
#Conclusion statement- when comparing male to females patients, mean amount of medications taken by female patients is higher than male patients.
